# %%
import pandas as pd
import numpy as np

# %%
vic400k = pd.read_csv('Farm_dams_data/vic_400k_dams.csv')

# %%
vic400k.head()
# Out:
#                                                  WKT CURRENCY PLAN_ACCUR  \
# 0  MULTIPOLYGON (((143.3774115 -35.576431,143.377...     2005     +/- 5m
# 1  MULTIPOLYGON (((143.352498 -35.5824155,143.352...     2005     +/- 5m
# 2  MULTIPOLYGON (((143.4013525 -35.610099999,143....     2005     +/- 5m
# 3  MULTIPOLYGON (((143.401754 -35.619457,143.4015...     2005     +/- 5m
# 4  MULTIPOLYGON (((143.40725 -35.583249,143.40728...     2005     +/- 5m
#
#           FEATSOURCE  BASIN  SDL_ID      FEAT_TYPE  VOL_ML_EST   SURFAREAM2  \
# 0  Satellite imagery  Avoca     408  Rural Storage    4.967839  3473.912628
# 1  Satellite imagery  Avoca     408  Rural Storage    4.139367  3025.885745
# 2  Satellite imagery  Avoca     408  Rural Storage    1.593328  1469.091450
# 3  Satellite imagery  Avoca     408  Rural Storage    1.512753  1412.511557
# 4  Satellite imagery  Avoca     408  Rural Storage    3.087369  2423.670868
#
# ...

# %%
vic500dams = vic400k.sample(n=500, random_state=42)

# %%
vic500dams.shape
# Out:
# (500, 17)

# %%
vic500dams.head()
# Out:
#                                                       WKT CURRENCY PLAN_ACCUR  \
# 315481  MULTIPOLYGON (((141.980985499 -35.975174,141.9...     2005     +/- 5m
# 117386  MULTIPOLYGON (((142.549820041 -37.623530784,14...  Mar2010     +/- 5m
# 163319  MULTIPOLYGON (((142.424877116 -37.874490558,14...  Mar2010     +/- 5m
# 253106  MULTIPOLYGON (((144.370624176 -37.907457296,14...      NaN     +/- 5m
# 268668  MULTIPOLYGON (((146.3141405 -36.44206,146.3140...     2005     +/- 5m
#
#                FEATSOURCE          BASIN   SDL_ID               FEAT_TYPE  \
# 315481  Satellite imagery   Wimmera-Avon      415           Rural Storage
# 117386     Aerial Imagery        Glenelg  2380505           Rural Storage
# 163319     Aerial Imagery  Hopkins River  2360101           Rural Storage
# 253106     Aerial Imagery      Moorabool  2320203           Rural Storage
# 268668  Satellite imagery          Ovens  4030804  Rural Licensed Storage
#
# ...

# %%
vic500dams.to_csv('vic_500_dams.csv', index=False)
